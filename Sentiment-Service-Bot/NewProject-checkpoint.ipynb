# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai
from datetime import datetime
import re
import string
import matplotlib.pyplot as plt

# %%
SENTIMENT_DICT = {

'מושלם': 3,
'כיף': 2,
'מדהים': 3,
'אהבתי': 2,
'בטוח': 1,
'זול': 1,
'מאורגן': 2,

'יקר': -2,
'מסוכן': -3,
'מבולגן': -2,
'מבלבל': -2,
'לא-מובן': -1,
'קור': -1,
}

# %%
class ServiceManager:
    def __init__(self):
        self.api_key = "AIzaSyDDGxbc-ow1M1ainaIscAhYxhTws3JHgzY"
        self.history = []
        self.model_name = "gemini-2.5-flash"
        self.client=self._connect_to_api()
        self.system_prompt = ("""
                               Role: You are a travel planning assistant helping users create personalized itineraries.
                               Tone: Speak clearly, politely, and professionally in every response.
                               Behavior: Ask clarifying questions, provide multiple options, and respond reliably.
                               Limits: Do not give unrelated, unsafe, or inaccurate advice outside travel planning.
                              """)
    
    def _connect_to_api(self):
        try:
            import google.generativeai as genai
            genai.configure(api_key=self.api_key)
            self.connected = True
            return genai
        except Exception as e:
            self.connected = False
            raise ConnectionError(f"API connection failed: {e}")
            
    def check_api_connection(self):
        if hasattr(self, "connected") and self.connected:
                return "Connection OK"
        else:
                return "Connection FAILED"


    def save_message(self,sender,text):
        self.history.append({"sender":sender , "text":text,"time":datetime.now().isoformat()})

        
    def send_question(self, user_text):
        try:
            self.save_message("user", user_text)
            history_text = "\n".join(f"{msg['sender']}: {msg['text']}" for msg in self.history)
            
            # שימוש ב-Client החדש
            response = self.client.generate_text(
                model="gemini-2.5-flash",
                prompt=history_text
            )
            bot_text = response.text.strip()
            self.save_message("bot", bot_text)
            return bot_text
        except Exception as e:
            return f"sending the question failed: {e}"

             
    def run_conversation(self):
         print("שלום! איך אפשר לעזור לך? (כתבי 'סיום' כדי לצאת)")
         while True:
             user_input = input("את: ")
             if user_input.strip().lower() == "סיום":
                 print("השיחה הסתימה! תודה.")
                 break
             bot_response=self.send_question(user_input)
             if bot_response.startswith("Sending the question failed"):
                  print("אירעה שגיאה, נסי שוב.")
             else:
                  print("בוט:", bot_response)
    def save_history_to_file( self, filename="chat_history.json"):
        try:
            with open(filename, "w", encoding="utf-8") as f:
                json.dump(self.history, f, ensure_ascii=False, indent=4)
            return True
        except Exception as e:
            print(f"שגיאה בשמירה של הקובץ: {e}")
            return False

    def load_history_from_file(self, filename="chat_history.json"):
        try:
            with open(filename, "r", encoding="utf-8") as f:
                self.history = json.load(f)
            print(f"היסטוריה נטענה בהצלחה מקובץ {filename}")
        except FileNotFoundError:
            print(f"הקובץ {filename} לא נמצא. יוצרת היסטוריה ריקה.")
            self.history = []
        except json.JSONDecodeError:
            print(f"שגיאה בקריאת הקובץ {filename}. פורמט JSON לא תקין.")
            self.history = []
        except Exception as e:
            print(f"שגיאה בטעינת ההיסטוריה: {e}")
            self.history = []

    def clean_text(text):
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\d+', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text.lower().split()
    
    def calculate_sentiment(self,text):
        score = 0
        clean_words=self.clean_text(text)
        for word in clean_words: 
            if word in SENTIMENT_DICT:
                score += SENTIMENT_DICT[word]
        return score
        
    def full_sentiment(messages):
        sentiment_scores = []
        for msg in messages:
            score = calculate_sentiment(msg)
            sentiment_scores.append(score)

# %%
bot = ServiceManager()
answer = bot.run_conversation()
print(answer)
# Out:
# שלום! איך אפשר לעזור לך? (כתבי 'סיום' כדי לצאת)
# את:  שלום
# בוט: sending the question failed: module 'google.generativeai' has no attribute 'generate_text'
# את:  סיום
# השיחה הסתימה! תודה.
# None

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(cumulative_sentiment)+1), cumulative_sentiment, marker='o', color='blue')
plt.title("מגמת סנטימנט לאורך השיחה")
plt.xlabel("מספר הודעה")
plt.ylabel("סנטימנט מצטבר")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 plt.figure(figsize=(10, 5))
# ----> 2 plt.plot(range(1, len(cumulative_sentiment)+1), cumulative_sentiment, marker='o', color='blue')
#       3 plt.title("מגמת סנטימנט לאורך השיחה")
#       4 plt.xlabel("מספר הודעה")
#
# NameError: name 'cumulative_sentiment' is not defined
